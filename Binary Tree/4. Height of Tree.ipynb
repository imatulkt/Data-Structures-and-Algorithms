# %% [markdown]
# ## **Height / Depth of Tree Traversal**

# %% [markdown]
# ### Leetcode 104: Maximum Depth of Binary Tree
# Link: https://leetcode.com/problems/maximum-depth-of-binary-tree/
#
# Explanation: https://www.youtube.com/watch?v=eD3tmO66aBA
#
#
# ![depth.PNG](data:image/png;base64,...)

# %%
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        if root == None:
            return 0
        leftside = 1 + self.maxDepth(root.left)
        rightside = 1 + self.maxDepth(root.right)
        return max(leftside, rightside)
