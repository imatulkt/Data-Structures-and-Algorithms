# %% [markdown]
# # **BINARY TREE**

# %% [markdown]
# A binary tree is a tree data structure in which each node has at most two children, which are referred to as the left child and the right child.
# ![BT.png](data:image/png;base64,...)

# %% [markdown]
# ## **Types of Binary Tree**

# %% [markdown]
# ![Types.png](data:image/png;base64,...)

# %% [markdown]
# 1.   **Full**: Every node of this tree has either 0 or 2 children
# 2.   **Complete**: All levels are completely filled except last level. The last level has all nodes on left as possible.
# 3.   **Perfect**: All leaf nodes are at same level.
# 4.   **Balanced**: A tree with maximum height of log2(N), where N is number of nodes.
# 5.   **Degenerate** : Skew Trees.

# %% [markdown]
# ## Binary Tree in Competitive Programming

# %% [markdown]
# In Python , the given below example tree is generally created as follows:
# ![binary-tree2.png](data:image/png;base64,...)

# %%
class Node:
  def __init__(self,key):
    self.left = None
    self.key = key
    self.right = None

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(5)
root.left.right = Node(6)

# %% [markdown]
# Above process is cumbersome as number of nodes, keeps on increasing. Hence all competitive programming enviornment build a tree and gives the root node as argument inside the function that you need to complete. So from CP point of view, we don't have to read input and build tree.
#
# Below is of sample LeetCode:
#
#
# ![Capture.PNG](data:image/png;base64,...)
